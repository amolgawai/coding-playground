# %%
import pandas as pd

# %%
df = pd.read_csv("taxi_rides.csv")
df
# Out:
#                 id  vendor_id pickup_datetime dropoff_datetime  \
# 0        id3487442          2   2/29/16 18:39    2/29/16 18:42
# 1        id1145809          2   5/16/16 23:15    5/16/16 23:31
# 2        id3499387          1   1/25/16 19:45    1/25/16 19:54
# 3        id0753277          1   1/27/16 22:29    1/27/16 22:29
# 4        id2134482          1   1/22/16 16:13    1/22/16 16:13
# ...            ...        ...             ...              ...
# 1048463  id0982904          1   4/28/16 13:32    4/28/16 14:14
# 1048464  id1001696          1   2/24/16 21:02    2/24/16 21:25
# 1048465  id1146400          1   2/15/16 18:57    2/15/16 19:02
# 1048466  id1510552          2    1/6/16 20:40     1/6/16 20:51
# 1048467  id2306955          1    5/7/16 18:58     5/7/16 19:12
#
#          passenger_count  pickup_longitude  pickup_latitude  \
# 0                      1        -73.981819        40.768963
# 1                      6        -73.808487        40.687336
# ...

# %%
dur_mean = df["duration"].mean()
dur_mean
# Out:
# 962.1956263805857
